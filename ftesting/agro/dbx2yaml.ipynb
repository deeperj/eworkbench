# %% [raw]
# # Python definition of database structure
#
# # Define the various database tables as list in the iterator
# '''
# The datatypes defined here do not comply with the native python object or framework model types
# Efforts have been added to ensure names of datatypes are descriptive
# It is believed that the average database designer will be able to decipher what datatype
# to use for his/her target database or framework model. Below is a brief type description:
# DATATYPES
# =========
# asbie: represents a relationship or complex data structure. E.g a dictionary object or foreign field in a table
# name: repr alphanumeric string type of limited length. Default length set to 50 characters
# text: repr raw string type. Default length set to 200 characters
# code: repr alpanumeric string used to name a constant or flag. e.g PH_VALUE, COLOR_RED
# number: repr numeric type either as a number or string that can be parsed into a number type
# "date_": repr the date object
# datetime_: repr the datetime object
# time_: repr time object
# "identifier": repr a unique identification for an attribute e.g a primary key for a table, a unique number, or index
# amount: repr monetary values with their associated currency code
# boolean: repr bool True or False values
# binary: repr raw bytes or byte array like streams or object
#
# '''

# %%
database = {
        "AgroDocument":[
            # Agro Document extends the base UBL document model
            ('contract_number', "identifier"),            
            ('farm', "asbie"),            
            ('work_process', "asbie"),            
            ('profile', "text"),            
        ],
        "Farm":[
            # Farm
            ('fields', "asbie"),  # references the various arable regions on the farm
            ('name', "text"),
            ('owner', "asbie"),
            ('location', "asbie"),  # use address type or GPS reading here
            ('description', "text"),
            ('purpose', "text"),
            ('certificate', "asbie"),
            ('agric_programme', "asbie"),
            ('size', "asbie"),  # gives the calculated land mass for the farm. Not necessarily sum of field area
            ('farming_system', "text")
        ],
        "Certificate":[
            # Certificate
            ('first_certificate_date', "date_"),
            ('certification_agency', "text"),
            ('validity', "asbie"),
            ('certificate_number', "identifier"),
            ('certification_code', "code"),
            ('supporting_documents', "asbie"), # scanned paper documents where applicable
        ],
        "CertificationValidity":[
            # Certification Validity
            ('valid_for_purpose', "boolean"),
            ('farm_purpose', "text"),
            ('issue_date', "date_"),
            ('start_date', "date_"), # defaults to issue_date when not specified
            ('expiry_date', "date_"),            
        ],
        "FarmField":[
            # Field
            ('cultivation', "asbie"),            
            ('name_of_field', "name"),
            ('field_identification', "identifier"),
            ('unique_area_id', "identifier"),
            ('part_of_farm', 'text'),
            ('area', "number"),
            ('area_unit', "code"),
            ('spatial_data', "asbie"),
            ('land_use_restriction', "asbie"),
            ('assessment', "asbie"),
 # reference the soil_sample & analysis result            
        ],
        "Assessment":[
            # Assessment
            ('soil_sample', "asbie"),
            ('analysis', "asbie"),
            ('status', "asbie")
        ],
        "GenericStatus":[
            # Generic Status
            ('staus', "code"),
            ('status_name', "name"),
            ('meaning', "text")
        ],
        "RecordedStatus":[
            # Recorded Status @comment: references the present status of an entity
            ('status', "asbie"),
            ('status_date', "date_"),
            ('status_time', "time_")
        ],
        "LandUse":[
            # Land use
            ('land_use', "text"),  # text describing land use were land_use_code_type is insufficient
            ('land_use_type', "code"),  # values: PRIMARY_CROP, CATCH_CROP, PRECEEDING_CROP, LAND_USE_RESTRICTION
            ('farming_attribute', "code"), # values: PLOUGHLESS, DIRECT_SOWING
            ('land_use_restriction_type', "code"),
        ],        
        "FertilizationRecommendation":[
            # Fertilization Recommendation
            ('crops', "asbie"),
            ('agent', "asbie"),
            ('form_of_fertilizer', "asbie"),
            ('substance_contained', "text"),  # provide a list of content as delimieted string
            ('fertilizer', "asbie"),
            ('application_quantity', "number"),
            ('application_measured_unit', "code"),            
        ],
        "SampleBase":[
            # Sample @ base sample definition for soil and fertilizer samples
            ('recieved_date', "date_"),
            ('received_time', "time_"),
            ('description', "text"),
            ('comment', "text"),
            ('weight', "number"), 
            ('weight_unit', "code"),
            ('volume', "number"),
            ('volume_unit', "code"),
            ('composition', "text"),  # delimited string list
            ('information_source', "text"),  # name of agency performing test
            ('source_certificate', "text"),  # certification number or id for agency
            ('concentration', "text"), # delimited string list of composed substance and their measurements
            ('analysis_date', "date_"),
            ('analysis_time', "time_"),
        ],
        "SoilSample":[
            # Soil sample @extends Sample
            ('soil_name', "text"),  # Give (alternative) name to soil type where not available in code
            ('soil_type', "code"),
            ('reference_part_of_field', "text"),
            ('spatial_data', "text"),
            ('referenced_field', "asbie"),  # references the field segment on farm
            ('depth', "number"),
            ('depth_unit', "code"),
            ('depth_range', "text"),
            ('analysis_method', "text"),
            ('soil_heaviness', "text"),
            ('soil_nutrient_classification', "text"),
            ('soil_texture', "text"),
        ],
        "AnalysisResult":[
            # Analysis Result
            ('abstract_analysis', "text"),
            ('parameters', "text"),  # delimited string list. e.g {'PH_VALUE': ("method", "value", "classification" )}
            ('description', "text"),
            ('method', "text"),
            ('comment', "text"),
            ('sample', "asbie"),            
        ],
        "FertilizerSample":[
            # Fertilizer sample @extends Sample
            ('fertilizer', "asbie"),            
        ],
        "Fertilizer":[
            # Fertilizer
            ('fertilizer_brand', "text"),  # general market brand name
            ('fertlizer_name', "text"),  # specific manufacturer name
            ('fertilizer_type', "code"),
            ('fertilizer_manufacturer', "asbie"),  # the registered manufacturer in database of text for others
            ('supplier', "asbie"),  # the agent supplying fertilizer
            ('fertilizer_form', "text")
        ],
        "FieldCultivation":[
            # Field Cultivation
            ('field', "asbie"),
            ('reference_field_part', "asbie"),
            ('duration_of_use', "number"),
            ('duration_unit', "code"),                        
        ],
        "Crop":[
            # Crop
            ('field', "asbie"),
            ('monetary_value_per_hectar', "number"),
            ('monetary_value_currency', "code"),
            ('crop_growth_event', "asbie"),
            ('botanical_name', "name"),
            ('cultural_name', "name"),
            ('description', "text"),
        ],
        "CropGrowthStage":[
            # Crop Growth Stage
            ('growth_stage', "text"),
            ('"date_"recorded', "date_"),
            ('time_recorded', "time_"),
            ('observer', "text"),  # reference unique id of user that observed growth or name of agent/3rd party
            ('reported_by', "asbie"),  # user reporting growth stage
            
        ],
        "CropSpecies":[
            # Crop Species
            ('crop', "asbie"),
            ('name', "text"),
            ('variety', "code"),
            ('genetically_modified_organism', "boolean"),            
        ],
        "Harvest":[
            # Harvest
            ('crop', "asbie"),
            ('harvested_quantity', "number"),
            ('yield_quantity', "number"),
            ('quantity_unit', "code"),
            # The code or string repr which can be parsed by target enum type.
            # The enum will have a default OTHER for cases not yet identified
            # Enum flag OTHER will enable collection and processing user's text data
            ('harvest_quality', "code"),
            ('field', "asbie"),
            ('start_date', "date_"),
            ('end_date', "date_")            
        ],
        "Activity":[
            # Activity
            ('daily_start', "datetime_"),
            ('daily_end', "datetime_"),
            ('activity', "text"),
            ('comment', "text"),
            ('work_done', "text"),
            ('percentage_executed', "number"),
            ('reference', "asbie")  # generic reference to Harvest, Cultivation and other farming activities
        ],
        "Weather":[
            # Weather
            ('temperature', "number"),
            ('temperature_unit', "code"),
            ('wind_speed', "number"),
            ('wind_speed_unit', "code"),
            ('humidity', "number"),
            ('humidity_unit', "code"),
            ('precipitation', "number"),
            ('precipitation_unit', "code"),
            ('solar_radiation', "number"),
            ('solar_radiation_unit', "code"),
            ('reported_by', "asbie"),
  # can be weather station or 3rd party agent
            ('reported_date', "date_"),
            ('reported_time', "time_"),
            ('measured_date', "date_"),
  # use this field for weather condition measured by on farm
            ('measured_time', "time_"),
            ('measured_by', "asbie"),
        ],
        "Contamination":[
            # Contamination
            ('contaimination_type', "text"),
            ('contamination_degree', "text"),
            ('noticed_date', "date_"),
            ('noticed_time', "time_"),
            ('reported_by', "asbie"),
            ('affected_fields', "asbie"),
            
        ],               
        "AgriculturalProgramme":[
            # Agricultural Programme @e.g palm seedling donations
            ('start', "datetime_"),
            ('end', "datetime_"),
            ('invitations', "asbie"),
            ('consultants', "asbie"),
            ('purpose', "text"),
            ('description', "text"),
            ('kpis', "asbie"),
            ('targets', "text"),
            ('comments', "text"),
            ('status', "asbie"),
        ],
        "ProgrammePerformance":[
            # Programme Performance
            ('participants','text' ),
 # actual record of participants as against invitation            
            ('programme_activities','text' ),
            ('comments', 'text'),
            ('learning_points', 'text'),
  # learning from the event by organisers
            ('recommendations', 'text'),
  # should hold organisers recommendations for later
            ('participant_suggestions','text' ),
 # should hold participant's suggestions/recommendations
            ('event_coverage', "binary"),  # uploaded photos or videos
            ('activity', "asbie")  # reference the generic activity model for daily activities
        ],
        "MeasuredKPI":[
            # Measured KPI
            ('measured_kpis', "asbie"),
  # delimited text for the KPIs measured with their unit
            ('impact_assessment', "text"),
            ('programme_performance', "asbie")
        ]
}

# %% [raw]
# # database["Farm"][0][1]='asbie'
# # database["Farm"][0][0]='fields'
# '''
# for key in PIX0:
#     NUM = input("What is the Resolution of %s?"  % key)
#     if NUM == PIX0[key]:
#         print ("Nice Job!")
#         count = count + 1
#     else:
#         print("I'm sorry but thats wrong. The correct answer was: %s." % PIX0[key] )
# '''

# %% [raw]
# Class:
#     Name: GeneratedClassCode
#     Super: Whatever
#     DocString: You better comment this Class
#     Args: firstArg, secondArg
#     Kwds: this=that, andThat=thisThing
#     Methods:
#         sync_method:
#             Sig:
#                 Sync: True
#                 Args: date
#                 Kwds: keywords
#                 DocString: This is my doc string
#         unsynced_method:
#             Sig:
#                 Sync: False
#                 Args:
#                 Kwds:
#                 DocString: This is my other doc string
#
# class GeneratedClassCode(Whatever):
#   '''
#     You better comment this Class
#   '''
#     def __init__(self, firstArg, secondArg, this=that, andThat=thisThing):
#       '''
#         Comment this Method
#       '''
#       Whatever.__init__(self)
#       try:
#         self.generatedClassCodeLock = threading.RLock()
#         self.firstArg = firstArg
#         self.secondArg = secondArg
#         self.this = that
#         self.andThat = thisThing
#
#       except Exception, e:
#         raise Exception(
#           'Raising Exception "%s" from %s.%s()'%(e, self.__class__.__name__, str(inspect.stack()[0][3]))
#         )

# %% [raw]
# yaml={}
# for table in database:
#     yf={}
#     for field in database[table]:
#         #print("table=",table,"; field=",field[0])
#         yf[field[0]]=field[1]
#     yaml[table]=yf
# yaml

# %%
classes=[]

for table in database:
    y={};yaml={};yf={}
    for field in database[table]:
        yf[field[0]]=field[1]
    y["Name"]=table
    y["Super"]='models.Model'
    y["DocString"]='You better comment this class'
    y["Args"]=database[table]
    y["Kwds"]=None
    y["Methods"]=None
    yaml['Class']=y
    classes.append(yaml)
classes
# Out:
# [{'Class': {'Args': {'contract_number': 'identifier',
#     'farm': 'asbie',
#     'profile': 'text',
#     'work_process': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'AgroDocument',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'agric_programme': 'asbie',
#     'certificate': 'asbie',
#     'description': 'text',
#     'farming_system': 'text',
#     'fields': 'asbie',
#     'location': 'asbie',
#     'name': 'text',
#     'owner': 'asbie',
#     'purpose': 'text',
#     'size': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Farm',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'certificate_number': 'identifier',
#     'certification_agency': 'text',
#     'certification_code': 'code',
#     'first_certificate_date': 'date_',
#     'supporting_documents': 'asbie',
#     'validity': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Certificate',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'expiry_date': 'date_',
#     'farm_purpose': 'text',
#     'issue_date': 'date_',
#     'start_date': 'date_',
#     'valid_for_purpose': 'boolean'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'CertificationValidity',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'area': 'number',
#     'area_unit': 'code',
#     'assessment': 'asbie',
#     'cultivation': 'asbie',
#     'field_identification': 'identifier',
#     'land_use_restriction': 'asbie',
#     'name_of_field': 'name',
#     'part_of_farm': 'text',
#     'spatial_data': 'asbie',
#     'unique_area_id': 'identifier'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'FarmField',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'analysis': 'asbie',
#     'soil_sample': 'asbie',
#     'status': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Assessment',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'meaning': 'text',
#     'status_name': 'name',
#     'staus': 'code'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'GenericStatus',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'status': 'asbie',
#     'status_date': 'date_',
#     'status_time': 'time_'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'RecordedStatus',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'farming_attribute': 'code',
#     'land_use': 'text',
#     'land_use_restriction_type': 'code',
#     'land_use_type': 'code'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'LandUse',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'agent': 'asbie',
#     'application_measured_unit': 'code',
#     'application_quantity': 'number',
#     'crops': 'asbie',
#     'fertilizer': 'asbie',
#     'form_of_fertilizer': 'asbie',
#     'substance_contained': 'text'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'FertilizationRecommendation',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'analysis_date': 'date_',
#     'analysis_time': 'time_',
#     'comment': 'text',
#     'composition': 'text',
#     'concentration': 'text',
#     'description': 'text',
#     'information_source': 'text',
#     'received_time': 'time_',
#     'recieved_date': 'date_',
#     'source_certificate': 'text',
#     'volume': 'number',
#     'volume_unit': 'code',
#     'weight': 'number',
#     'weight_unit': 'code'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'SampleBase',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'analysis_method': 'text',
#     'depth': 'number',
#     'depth_range': 'text',
#     'depth_unit': 'code',
#     'reference_part_of_field': 'text',
#     'referenced_field': 'asbie',
#     'soil_heaviness': 'text',
#     'soil_name': 'text',
#     'soil_nutrient_classification': 'text',
#     'soil_texture': 'text',
#     'soil_type': 'code',
#     'spatial_data': 'text'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'SoilSample',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'abstract_analysis': 'text',
#     'comment': 'text',
#     'description': 'text',
#     'method': 'text',
#     'parameters': 'text',
#     'sample': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'AnalysisResult',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'fertilizer': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'FertilizerSample',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'fertilizer_brand': 'text',
#     'fertilizer_form': 'text',
#     'fertilizer_manufacturer': 'asbie',
#     'fertilizer_type': 'code',
#     'fertlizer_name': 'text',
#     'supplier': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Fertilizer',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'duration_of_use': 'number',
#     'duration_unit': 'code',
#     'field': 'asbie',
#     'reference_field_part': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'FieldCultivation',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'botanical_name': 'name',
#     'crop_growth_event': 'asbie',
#     'cultural_name': 'name',
#     'description': 'text',
#     'field': 'asbie',
#     'monetary_value_currency': 'code',
#     'monetary_value_per_hectar': 'number'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Crop',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'"date_"recorded': 'date_',
#     'growth_stage': 'text',
#     'observer': 'text',
#     'reported_by': 'asbie',
#     'time_recorded': 'time_'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'CropGrowthStage',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'crop': 'asbie',
#     'genetically_modified_organism': 'boolean',
#     'name': 'text',
#     'variety': 'code'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'CropSpecies',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'crop': 'asbie',
#     'end_date': 'date_',
#     'field': 'asbie',
#     'harvest_quality': 'code',
#     'harvested_quantity': 'number',
#     'quantity_unit': 'code',
#     'start_date': 'date_',
#     'yield_quantity': 'number'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Harvest',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'activity': 'text',
#     'comment': 'text',
#     'daily_end': 'datetime_',
#     'daily_start': 'datetime_',
#     'percentage_executed': 'number',
#     'reference': 'asbie',
#     'work_done': 'text'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Activity',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'humidity': 'number',
#     'humidity_unit': 'code',
#     'measured_by': 'asbie',
#     'measured_date': 'date_',
#     'measured_time': 'time_',
#     'precipitation': 'number',
#     'precipitation_unit': 'code',
#     'reported_by': 'asbie',
#     'reported_date': 'date_',
#     'reported_time': 'time_',
#     'solar_radiation': 'number',
#     'solar_radiation_unit': 'code',
#     'temperature': 'number',
#     'temperature_unit': 'code',
#     'wind_speed': 'number',
#     'wind_speed_unit': 'code'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Weather',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'affected_fields': 'asbie',
#     'contaimination_type': 'text',
#     'contamination_degree': 'text',
#     'noticed_date': 'date_',
#     'noticed_time': 'time_',
#     'reported_by': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'Contamination',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'comments': 'text',
#     'consultants': 'asbie',
#     'description': 'text',
#     'end': 'datetime_',
#     'invitations': 'asbie',
#     'kpis': 'asbie',
#     'purpose': 'text',
#     'start': 'datetime_',
#     'status': 'asbie',
#     'targets': 'text'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'AgriculturalProgramme',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'activity': 'asbie',
#     'comments': 'text',
#     'event_coverage': 'binary',
#     'learning_points': 'text',
#     'participant_suggestions': 'text',
#     'participants': 'text',
#     'programme_activities': 'text',
#     'recommendations': 'text'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'ProgrammePerformance',
#    'Super': 'models.Model'}},
#  {'Class': {'Args': {'impact_assessment': 'text',
#     'measured_kpis': 'asbie',
#     'programme_performance': 'asbie'},
#    'DocString': 'You better comment this class',
#    'Kwds': None,
#    'Methods': None,
#    'Name': 'MeasuredKPI',
#    'Super': 'models.Model'}}]

# %%
from django_gen import get_dict
from django_gen import DjangoGen
for c in classes:
    options=get_dict(c)
    print (DjangoGen.generate(options))
# Out:
# Class
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-7c2a9787fe44> in <module>()
#       3 for c in classes:
#       4     options=get_dict(c)
# ----> 5     print (DjangoGen.generate(options))
#
# ~/Dropbox/rtmp/src/cpp/embedded/eworkbench/ftesting/agro/django_gen.py in generate(options)
#     283   def generate(options):
#     284     c=DjangoGen(options)
# --> 285     return c.define_class()
#     286
#     287   @staticmethod
#
# ~/Dropbox/rtmp/src/cpp/embedded/eworkbench/ftesting/agro/django_gen.py in define_class(self)
#     250       classSeq.append(self.code_line('%s.__init__(self)'%self.options.ClassOptions.Super, tabIn=3))
#     251     memberLines = self.define_members(
# --> 252           self.get_args(self.options.ClassOptions.Args),
#     253           self.get_kwds(self.options.ClassOptions.Kwds))
#     254     classSeq.append(
#
# ~/Dropbox/rtmp/src/cpp/embedded/eworkbench/ftesting/agro/django_gen.py in get_args(self, line)
#     221     #print(line)
#     222     if line:
# --> 223       return line.keys() #[l[0] for l in line] #.replace(' ', '').split(',')
#     224   #
#     225   def define_members(self, args, kwds):
#
# AttributeError: 'ConfigOptions' object has no attribute 'keys'

# %% [raw]
# from django.db import models
# from django_extensions.db.fields import AutoSlugField
#
# class Article(models.Model):
#     '''An article with title, date and slug. The slug is not totally
#     unique but there will be no two articles with the same slug within
#     any month.
#     '''
#     title = models.CharField(max_length=200)
#     pub_date = models.DateField(auto_now_add=True)
#     slug = AutoSlugField(populate_from='title', unique_with='pub_date__month')
